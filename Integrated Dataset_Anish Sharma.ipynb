# %% [markdown]
# ## Industry Research, Data Collection & Integration.
#
# ### -> Importing Libraries.

# %%
import pandas as pd

# %% [markdown]
# ### 1).  Identifying and accessing relevant data sources.
#
# #### (i). Traffic data.

# %%
traffic_data = pd.read_csv("Dataset_Uber traffic.csv")
traffic_data['Datetime'] = pd.to_datetime(traffic_data['Datetime'], format='%d/%m/%y %H:%M', errors='coerce')
traffic_data.tail(60)
# Out:
#                  Datetime  Junction  Vehicles           ID
# 48060 2017-06-28 12:00:00         4        10  20170628124
# 48061 2017-06-28 13:00:00         4        14  20170628134
# 48062 2017-06-28 14:00:00         4        15  20170628144
# 48063 2017-06-28 15:00:00         4        17  20170628154
# 48064 2017-06-28 16:00:00         4        16  20170628164
# 48065 2017-06-28 17:00:00         4        14  20170628174
# 48066 2017-06-28 18:00:00         4        11  20170628184
# 48067 2017-06-28 19:00:00         4        15  20170628194
# 48068 2017-06-28 20:00:00         4        23  20170628204
# 48069 2017-06-28 21:00:00         4        17  20170628214
# 48070 2017-06-28 22:00:00         4        22  20170628224
# 48071 2017-06-28 23:00:00         4        18  20170628234
# 48072 2017-06-29 00:00:00         4        14  20170629004
# 48073 2017-06-29 01:00:00         4        11  20170629014
# 48074 2017-06-29 02:00:00         4        10  20170629024
# 48075 2017-06-29 03:00:00         4         5  20170629034
# 48076 2017-06-29 04:00:00         4         5  20170629044
# 48077 2017-06-29 05:00:00         4         4  20170629054
# 48078 2017-06-29 06:00:00         4         7  20170629064
# 48079 2017-06-29 07:00:00         4         6  20170629074
# 48080 2017-06-29 08:00:00         4         8  20170629084
# 48081 2017-06-29 09:00:00         4        14  20170629094
# 48082 2017-06-29 10:00:00         4        12  20170629104
# 48083 2017-06-29 11:00:00         4        15  20170629114
# 48084 2017-06-29 12:00:00         4        20  20170629124
# 48085 2017-06-29 13:00:00         4        17  20170629134
# 48086 2017-06-29 14:00:00         4        17  20170629144
# 48087 2017-06-29 15:00:00         4        16  20170629154
# 48088 2017-06-29 16:00:00         4        19  20170629164
# 48089 2017-06-29 17:00:00         4        17  20170629174
# 48090 2017-06-29 18:00:00         4        19  20170629184
# 48091 2017-06-29 19:00:00         4         9  20170629194
# 48092 2017-06-29 20:00:00         4        13  20170629204
# 48093 2017-06-29 21:00:00         4        12  20170629214
# 48094 2017-06-29 22:00:00         4        15  20170629224
# 48095 2017-06-29 23:00:00         4        11  20170629234
# 48096 2017-06-30 00:00:00         4         9  20170630004
# 48097 2017-06-30 01:00:00         4         7  20170630014
# 48098 2017-06-30 02:00:00         4         5  20170630024
# 48099 2017-06-30 03:00:00         4         6  20170630034
# 48100 2017-06-30 04:00:00         4         5  20170630044
# 48101 2017-06-30 05:00:00         4         5  20170630054
# 48102 2017-06-30 06:00:00         4         6  20170630064
# 48103 2017-06-30 07:00:00         4         4  20170630074
# 48104 2017-06-30 08:00:00         4         5  20170630084
# 48105 2017-06-30 09:00:00         4         7  20170630094
# 48106 2017-06-30 10:00:00         4        15  20170630104
# 48107 2017-06-30 11:00:00         4        14  20170630114
# 48108 2017-06-30 12:00:00         4         9  20170630124
# 48109 2017-06-30 13:00:00         4        11  20170630134
# 48110 2017-06-30 14:00:00         4        10  20170630144
# 48111 2017-06-30 15:00:00         4        14  20170630154
# 48112 2017-06-30 16:00:00         4        16  20170630164
# 48113 2017-06-30 17:00:00         4        16  20170630174
# 48114 2017-06-30 18:00:00         4        17  20170630184
# 48115 2017-06-30 19:00:00         4        11  20170630194
# 48116 2017-06-30 20:00:00         4        30  20170630204
# 48117 2017-06-30 21:00:00         4        16  20170630214
# 48118 2017-06-30 22:00:00         4        22  20170630224
# 48119 2017-06-30 23:00:00         4        12  20170630234

# %% [markdown]
# ### (ii). Weather data.

# %%
weather_data = pd.read_csv("Weather.csv")
weather_data['Datetime'] = pd.to_datetime(weather_data['Datetime'], format='%d/%m/%Y', errors='coerce')
weather_data
# Out:
#       Datetime  Temperature  Humidity  Precipitation  Windspeed
# 0   2015-11-01         17.0      75.6          0.000        8.3
# 1   2015-11-02         16.8      77.4          0.300        7.9
# 2   2015-11-03         16.2      78.1          0.800        8.3
# 3   2015-11-04         16.1      72.9          0.000        6.5
# 4   2015-11-05         16.7      62.9          1.500        9.0
# ..         ...          ...       ...            ...        ...
# 603 2017-06-26         28.7      70.2          0.900       24.1
# 604 2017-06-27         28.4      79.8          5.344       22.3
# 605 2017-06-28         25.2      91.3         19.666       27.7
# 606 2017-06-29         24.6      92.5          4.591       13.0
# 607 2017-06-30         25.6      89.9          0.043       16.6
#
# [608 rows x 5 columns]

# %% [markdown]
# ### (iii). Event data.

# %%
event_data = pd.read_csv("events.csv")
event_data['Datetime'] = pd.to_datetime(event_data['Datetime'], format='%Y-%m-%d', errors='coerce')
event_data
# Out:
#      Datetime                Event Name   Location            Type  \
# 0  2015-11-01           Diwali Festival  Pan India  Public Holiday
# 1  2015-11-02  Pro Kabaddi League Final  Hyderabad          Sports
# 2  2015-11-08          Coldplay Concert     Mumbai         Concert
# 3  2015-11-25        Guru Nanak Jayanti   Amritsar  Public Holiday
# 4  2015-12-01        Cricket Test Match      Delhi          Sports
# ..        ...                       ...        ...             ...
# 57 2017-05-19  Pro Kabaddi League Match  Bengaluru          Sports
# 58 2017-06-05        Cricket Test Match    Chennai          Sports
# 59 2017-06-10        Ed Sheeran Concert    Chennai         Concert
# 60 2017-06-15  Pro Kabaddi League Match     Mumbai          Sports
# 61 2017-06-21    International Yoga Day  Pan India  Public Holiday
#
#                                        Description
# 0                  Annual Hindu festival of lights
# 1   Final match of the Pro Kabaddi League Season 2
# 2            Live performance by the band Coldplay
# 3       Birthday of Guru Nanak(founder of Sikhism)
# 4        Test match between India and South Africa
# ..                                             ...
# 57               Professional Kabaddi league match
# 58         Test match between India and Bangladesh
# 59       Live performance by the singer Ed Sheeran
# 60               Professional Kabaddi league match
# 61     Global event promoting the practice of yoga
#
# [62 rows x 5 columns]

# %% [markdown]
# ### 2). Integrating data from various sources.
#
# #### Developing a data integration pipeline to merge Traffic, Weather, and Event data into a unified dataset, ensuring data is synchronized based on timestamps to align traffic data with corresponding weather conditions and events.

# %%
# Merging datasets on 'Datetime'
merge_data = pd.merge(traffic_data, weather_data, on=['Datetime'], how='left')
Integrated_Dataset = pd.merge(merge_data, event_data, on=['Datetime'], how='left')
print(merge_data)
print(Integrated_Dataset)
# Out:
#                  Datetime  Junction  Vehicles           ID  Temperature  \
# 0     2015-11-01 00:00:00         1        15  20151101001         17.0
# 1     2015-11-01 01:00:00         1        13  20151101011          NaN
# 2     2015-11-01 02:00:00         1        10  20151101021          NaN
# 3     2015-11-01 03:00:00         1         7  20151101031          NaN
# 4     2015-11-01 04:00:00         1         9  20151101041          NaN
# ...                   ...       ...       ...          ...          ...
# 48115 2017-06-30 19:00:00         4        11  20170630194          NaN
# 48116 2017-06-30 20:00:00         4        30  20170630204          NaN
# 48117 2017-06-30 21:00:00         4        16  20170630214          NaN
# 48118 2017-06-30 22:00:00         4        22  20170630224          NaN
# 48119 2017-06-30 23:00:00         4        12  20170630234          NaN
#
#        Humidity  Precipitation  Windspeed
# 0          75.6            0.0        8.3
# 1           NaN            NaN        NaN
# 2           NaN            NaN        NaN
# 3           NaN            NaN        NaN
# 4           NaN            NaN        NaN
# ...         ...            ...        ...
# 48115       NaN            NaN        NaN
# 48116       NaN            NaN        NaN
# 48117       NaN            NaN        NaN
# 48118       NaN            NaN        NaN
# 48119       NaN            NaN        NaN
#
# [48120 rows x 8 columns]
#                  Datetime  Junction  Vehicles           ID  Temperature  \
# 0     2015-11-01 00:00:00         1        15  20151101001         17.0
# 1     2015-11-01 01:00:00         1        13  20151101011          NaN
# 2     2015-11-01 02:00:00         1        10  20151101021          NaN
# 3     2015-11-01 03:00:00         1         7  20151101031          NaN
# 4     2015-11-01 04:00:00         1         9  20151101041          NaN
# ...                   ...       ...       ...          ...          ...
# 48115 2017-06-30 19:00:00         4        11  20170630194          NaN
# 48116 2017-06-30 20:00:00         4        30  20170630204          NaN
# 48117 2017-06-30 21:00:00         4        16  20170630214          NaN
# 48118 2017-06-30 22:00:00         4        22  20170630224          NaN
# 48119 2017-06-30 23:00:00         4        12  20170630234          NaN
#
#        Humidity  Precipitation  Windspeed       Event Name   Location  \
# 0          75.6            0.0        8.3  Diwali Festival  Pan India
# 1           NaN            NaN        NaN              NaN        NaN
# 2           NaN            NaN        NaN              NaN        NaN
# 3           NaN            NaN        NaN              NaN        NaN
# 4           NaN            NaN        NaN              NaN        NaN
# ...         ...            ...        ...              ...        ...
# 48115       NaN            NaN        NaN              NaN        NaN
# 48116       NaN            NaN        NaN              NaN        NaN
# 48117       NaN            NaN        NaN              NaN        NaN
# 48118       NaN            NaN        NaN              NaN        NaN
# 48119       NaN            NaN        NaN              NaN        NaN
#
#                  Type                      Description
# 0      Public Holiday  Annual Hindu festival of lights
# 1                 NaN                              NaN
# 2                 NaN                              NaN
# 3                 NaN                              NaN
# 4                 NaN                              NaN
# ...               ...                              ...
# 48115             NaN                              NaN
# 48116             NaN                              NaN
# 48117             NaN                              NaN
# 48118             NaN                              NaN
# 48119             NaN                              NaN
#
# [48120 rows x 12 columns]

# %% [markdown]
# ### 3). Handling data quality issues.
# #### (i). Cleaning the dataset by removing duplicates, handling missing values (imputation or removal), and correcting inconsistencies.

# %%
# Identify duplicate records
duplicate_mask = Integrated_Dataset.duplicated()
duplicates = Integrated_Dataset[duplicate_mask]
print(duplicates)

# Remove duplicates
Integrated_Dataset = Integrated_Dataset.drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [Datetime, Junction, Vehicles, ID, Temperature, Humidity, Precipitation, Windspeed, Event Name, Location, Type, Description]
# Index: []

# %%
# NOTE :- We will be only removing missing values from merged data of traffic and weather, as events occur ocassionaly.

# Removing rows with missing values 
merge_data = merge_data.dropna() 

# Reseting index
merge_data = merge_data.reset_index(drop=True)

print("\nDataset after removing rows with Missing Values:\n")
print(merge_data)

# Check for any remaining missing values
print(merge_data .isnull().sum())

Integrated_Dataset = pd.merge(merge_data, event_data, on=['Datetime'], how='left')
print(Integrated_Dataset)
# Out:
# Dataset after removing rows with Missing Values:
#
#        Datetime  Junction  Vehicles           ID  Temperature  Humidity  \
# 0    2015-11-01         1        15  20151101001         17.0      75.6
# 1    2015-11-02         1        14  20151102001         16.8      77.4
# 2    2015-11-03         1        21  20151103001         16.2      78.1
# 3    2015-11-04         1        18  20151104001         16.1      72.9
# 4    2015-11-05         1        19  20151105001         16.7      62.9
# ...         ...       ...       ...          ...          ...       ...
# 2000 2017-06-26         4         6  20170626004         28.7      70.2
# 2001 2017-06-27         4         9  20170627004         28.4      79.8
# 2002 2017-06-28         4         6  20170628004         25.2      91.3
# 2003 2017-06-29         4        14  20170629004         24.6      92.5
# 2004 2017-06-30         4         9  20170630004         25.6      89.9
#
#       Precipitation  Windspeed
# 0             0.000        8.3
# 1             0.300        7.9
# 2             0.800        8.3
# 3             0.000        6.5
# 4             1.500        9.0
# ...             ...        ...
# 2000          0.900       24.1
# 2001          5.344       22.3
# 2002         19.666       27.7
# 2003          4.591       13.0
# 2004          0.043       16.6
#
# [2005 rows x 8 columns]
# Datetime         0
# Junction         0
# Vehicles         0
# ID               0
# Temperature      0
# Humidity         0
# Precipitation    0
# Windspeed        0
# dtype: int64
#        Datetime  Junction  Vehicles           ID  Temperature  Humidity  \
# 0    2015-11-01         1        15  20151101001         17.0      75.6
# 1    2015-11-02         1        14  20151102001         16.8      77.4
# 2    2015-11-03         1        21  20151103001         16.2      78.1
# 3    2015-11-04         1        18  20151104001         16.1      72.9
# 4    2015-11-05         1        19  20151105001         16.7      62.9
# ...         ...       ...       ...          ...          ...       ...
# 2000 2017-06-26         4         6  20170626004         28.7      70.2
# 2001 2017-06-27         4         9  20170627004         28.4      79.8
# 2002 2017-06-28         4         6  20170628004         25.2      91.3
# 2003 2017-06-29         4        14  20170629004         24.6      92.5
# 2004 2017-06-30         4         9  20170630004         25.6      89.9
#
#       Precipitation  Windspeed                Event Name   Location  \
# 0             0.000        8.3           Diwali Festival  Pan India
# 1             0.300        7.9  Pro Kabaddi League Final  Hyderabad
# 2             0.800        8.3                       NaN        NaN
# 3             0.000        6.5                       NaN        NaN
# 4             1.500        9.0                       NaN        NaN
# ...             ...        ...                       ...        ...
# 2000          0.900       24.1                       NaN        NaN
# 2001          5.344       22.3                       NaN        NaN
# 2002         19.666       27.7                       NaN        NaN
# 2003          4.591       13.0                       NaN        NaN
# 2004          0.043       16.6                       NaN        NaN
#
#                 Type                                     Description
# 0     Public Holiday                 Annual Hindu festival of lights
# 1             Sports  Final match of the Pro Kabaddi League Season 2
# 2                NaN                                             NaN
# 3                NaN                                             NaN
# 4                NaN                                             NaN
# ...              ...                                             ...
# 2000             NaN                                             NaN
# 2001             NaN                                             NaN
# 2002             NaN                                             NaN
# 2003             NaN                                             NaN
# 2004             NaN                                             NaN
#
# [2005 rows x 12 columns]

# %%
# Merging the new_merged_dataset and event dataset. 
Integrated_Dataset = pd.merge(new_merged_data, event_data, on=['Datetime'], how='left')

# Handle missing values in the final merged dataset
# For simplicity, let's fill missing values with a placeholder 'Unknown'.
Integrated_Dataset.fillna({
    'Event Name': 'No Event',
    'Location': 'NA',
    'Type': 'NA',
    'Description': 'NA',
    'Source': 'NA'
}, inplace=True)

#Displaying Final Integrated Dataset after handling missing values
print(Integrated_Dataset)
# Out:
#        Datetime  Junction  Vehicles           ID  Temperature  Humidity  \
# 0    2015-11-01         1        15  20151101001         17.0      75.6
# 1    2015-11-02         1        14  20151102001         16.8      77.4
# 2    2015-11-03         1        21  20151103001         16.2      78.1
# 3    2015-11-04         1        18  20151104001         16.1      72.9
# 4    2015-11-05         1        19  20151105001         16.7      62.9
# ...         ...       ...       ...          ...          ...       ...
# 2000 2017-06-26         4         6  20170626004         28.7      70.2
# 2001 2017-06-27         4         9  20170627004         28.4      79.8
# 2002 2017-06-28         4         6  20170628004         25.2      91.3
# 2003 2017-06-29         4        14  20170629004         24.6      92.5
# 2004 2017-06-30         4         9  20170630004         25.6      89.9
#
#       Precipitation  Windspeed                Event Name   Location  \
# 0             0.000        8.3           Diwali Festival  Pan India
# 1             0.300        7.9  Pro Kabaddi League Final  Hyderabad
# 2             0.800        8.3                  No Event         NA
# 3             0.000        6.5                  No Event         NA
# 4             1.500        9.0                  No Event         NA
# ...             ...        ...                       ...        ...
# 2000          0.900       24.1                  No Event         NA
# 2001          5.344       22.3                  No Event         NA
# 2002         19.666       27.7                  No Event         NA
# 2003          4.591       13.0                  No Event         NA
# 2004          0.043       16.6                  No Event         NA
#
#                 Type                                     Description
# 0     Public Holiday                 Annual Hindu festival of lights
# 1             Sports  Final match of the Pro Kabaddi League Season 2
# 2                 NA                                              NA
# 3                 NA                                              NA
# 4                 NA                                              NA
# ...              ...                                             ...
# 2000              NA                                              NA
# 2001              NA                                              NA
# 2002              NA                                              NA
# 2003              NA                                              NA
# 2004              NA                                              NA
#
# [2005 rows x 12 columns]

# %% [markdown]
# ### (ii). Normalizing or standardizing data to bring different variables to a common scale.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Integrated_Dataset['vehicle_scaled'] = scaler.fit_transform(Integrated_Dataset[['Vehicles']])

# Display normalized data
print("\nNormalized Integrated Dataset :")
print(Integrated_Dataset.head(10))
# Out:
# Normalized Integrated Dataset :
#     Datetime  Junction  Vehicles           ID  Temperature  Humidity  \
# 0 2015-11-01         1        15  20151101001         17.0      75.6
# 1 2015-11-02         1        14  20151102001         16.8      77.4
# 2 2015-11-03         1        21  20151103001         16.2      78.1
# 3 2015-11-04         1        18  20151104001         16.1      72.9
# 4 2015-11-05         1        19  20151105001         16.7      62.9
# 5 2015-11-06         1        16  20151106001         15.6      67.5
# 6 2015-11-07         1        16  20151107001         15.4      73.0
# 7 2015-11-08         1        13  20151108001         15.6      71.6
# 8 2015-11-09         1        13  20151109001         15.6      72.9
# 9 2015-11-10         1        19  20151110001         15.8      69.4
#
#    Precipitation  Windspeed                Event Name   Location  \
# 0            0.0        8.3           Diwali Festival  Pan India
# 1            0.3        7.9  Pro Kabaddi League Final  Hyderabad
# 2            0.8        8.3                  No Event         NA
# 3            0.0        6.5                  No Event         NA
# 4            1.5        9.0                  No Event         NA
# 5            0.0        7.6                  No Event         NA
# 6            0.2        8.3                  No Event         NA
# 7            0.2        7.9          Coldplay Concert     Mumbai
# 8            0.7        7.6                  No Event         NA
# 9            1.5        5.4                  No Event         NA
#
#              Type                                     Description  \
# 0  Public Holiday                 Annual Hindu festival of lights
# 1          Sports  Final match of the Pro Kabaddi League Season 2
# 2              NA                                              NA
# 3              NA                                              NA
# 4              NA                                              NA
# 5              NA                                              NA
# 6              NA                                              NA
# 7         Concert           Live performance by the band Coldplay
# 8              NA                                              NA
# 9              NA                                              NA
#
#    vehicle_scaled
# 0       -0.446144
# 1       -0.498381
# 2       -0.132718
# 3       -0.289431
# 4       -0.237193
# 5       -0.393906
# 6       -0.393906
# 7       -0.550619
# 8       -0.550619
# 9       -0.237193

# %% [markdown]
# ### ->  Saving the Final Merged dataset to CSV.

# %%
Integrated_Dataset.to_csv('Integrated_Dataset.csv', index=False)

# %% [markdown]
# ### -> Importing the Integrated Dataset.

# %%
df = pd.read_csv('Integrated_Dataset.csv')
df
# Out:
#         Datetime  Junction  Vehicles           ID  Temperature  Humidity  \
# 0     2015-11-01         1        15  20151101001         17.0      75.6
# 1     2015-11-02         1        14  20151102001         16.8      77.4
# 2     2015-11-03         1        21  20151103001         16.2      78.1
# 3     2015-11-04         1        18  20151104001         16.1      72.9
# 4     2015-11-05         1        19  20151105001         16.7      62.9
# ...          ...       ...       ...          ...          ...       ...
# 2000  2017-06-26         4         6  20170626004         28.7      70.2
# 2001  2017-06-27         4         9  20170627004         28.4      79.8
# 2002  2017-06-28         4         6  20170628004         25.2      91.3
# 2003  2017-06-29         4        14  20170629004         24.6      92.5
# 2004  2017-06-30         4         9  20170630004         25.6      89.9
#
#       Precipitation  Windspeed                Event Name   Location  \
# 0             0.000        8.3           Diwali Festival  Pan India
# 1             0.300        7.9  Pro Kabaddi League Final  Hyderabad
# 2             0.800        8.3                  No Event        NaN
# 3             0.000        6.5                  No Event        NaN
# 4             1.500        9.0                  No Event        NaN
# ...             ...        ...                       ...        ...
# 2000          0.900       24.1                  No Event        NaN
# 2001          5.344       22.3                  No Event        NaN
# 2002         19.666       27.7                  No Event        NaN
# 2003          4.591       13.0                  No Event        NaN
# 2004          0.043       16.6                  No Event        NaN
#
#                 Type                                     Description  \
# 0     Public Holiday                 Annual Hindu festival of lights
# 1             Sports  Final match of the Pro Kabaddi League Season 2
# 2                NaN                                             NaN
# 3                NaN                                             NaN
# 4                NaN                                             NaN
# ...              ...                                             ...
# 2000             NaN                                             NaN
# 2001             NaN                                             NaN
# 2002             NaN                                             NaN
# 2003             NaN                                             NaN
# 2004             NaN                                             NaN
#
#       vehicle_scaled
# 0          -0.446144
# 1          -0.498381
# 2          -0.132718
# 3          -0.289431
# 4          -0.237193
# ...              ...
# 2000       -0.916283
# 2001       -0.759570
# 2002       -0.916283
# 2003       -0.498381
# 2004       -0.759570
#
# [2005 rows x 13 columns]
